# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# Create a ticker object for Amazon
amzn = yf.Ticker("AMZN")

# Fetch historical stock prices
hist = amzn.history(period="max")

# Fetch analysis for earnings estimates
balance = amzn.get_balance_sheet()

balance

# # Since get_analysis() returns future earnings estimates, let's focus on what's available
# # For historical comparison, we'll stick to stock price data from 2009 to 2023
# hist = hist[(hist.index.year >= 2009) & (hist.index.year <= 2023)]

# # Close price at the end of each year
# yearly_prices = hist['Close'].resample('Y').last()

# # Prepare the plot
# fig, ax1 = plt.subplots(figsize=(14, 8))

# color = 'tab:red'
# ax1.set_xlabel('Year')
# ax1.set_ylabel('Stock Price', color=color)
# ax1.plot(yearly_prices.index.year, yearly_prices, color=color, label='Stock Price')
# ax1.tick_params(axis='y', labelcolor=color)

# # Instantiate a second y-axis to share the same x-axis
# ax2 = ax1.twinx()

# color = 'tab:blue'
# ax2.set_ylabel('Earnings Estimates', color=color)  # we already handled the x-label with ax1

# # Plotting earnings estimates - using Earnings Estimate for the next fiscal year as an example
# # Note: analysis['Earnings Estimate'] might need adjustment based on the actual structure of the returned DataFrame
# if 'Earnings Estimate' in analysis and 'Avg. Estimate' in analysis['Earnings Estimate']:
#     future_years = analysis['Earnings Estimate'].columns
#     earnings_estimates = analysis['Earnings Estimate'].loc['Avg. Estimate']
#     ax2.plot(future_years, earnings_estimates, color='green', label='Earnings Estimate')
# else:
#     print("Earnings estimates data not available in the expected format.")

# ax2.tick_params(axis='y', labelcolor=color)

# # Trick to place legend together
# lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# ax2.legend(lines + lines2, labels + labels2, loc=0)

# fig.tight_layout()  # to make sure everything fits without overlapping
# plt.title('Amazon Stock Price and Earnings Estimates (2009-2023)')
# plt.show()
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                                    2023-12-31      2022-12-31  \
# TreasurySharesNumber                              515000000.0     515000000.0
# OrdinarySharesNumber                            10383000000.0   10242000000.0
# ShareIssued                                     10898000000.0   10757000000.0
# NetDebt                                                   NaN   13262000000.0
# TotalDebt                                      135611000000.0  140118000000.0
# TangibleBookValue                              171399000000.0  119658000000.0
# InvestedCapital                                260189000000.0  213193000000.0
# ...
